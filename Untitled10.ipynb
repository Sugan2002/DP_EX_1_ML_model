# %% [markdown]
# <a href="https://colab.research.google.com/github/Sugan2002/DP_EX_1_ML_model/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import tensorflow as tf

# %%
worksheet = gc.open('FirstDataset').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame(rows[1:], columns=rows[0])
df = df.astype({'X':'float'})
df = df.astype({'Y':'float'})
df.head(n=10)
# Out:
#       X      Y
# 0  10.0   25.0
# 1  20.0   45.0
# 2  30.0   65.0
# 3  40.0   85.0
# 4  50.0  105.0
# 5  60.0  125.0
# 6  70.0  145.0
# 7  80.0  165.0
# 8  90.0  185.0

# %%
df.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
df=df.astype({'X':'float'})
df=df.astype({'Y':'float'})

# %%
df.dtypes
# Out:
# X    float64
# Y    float64
# dtype: object

# %%
x=df[['X']].values

# %%
x
# Out:
# array([[10.],
#        [20.],
#        [30.],
#        [40.],
#        [50.],
#        [60.],
#        [70.],
#        [80.],
#        [90.]])

# %%
y=df[['Y']].values

# %%
y
# Out:
# array([[ 25.],
#        [ 45.],
#        [ 65.],
#        [ 85.],
#        [105.],
#        [125.],
#        [145.],
#        [165.],
#        [185.]])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.33,random_state=50)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
X_train.shape
# Out:
# (6, 1)

# %%
X_test.shape
# Out:
# (3, 1)

# %%
X_test
# Out:
# array([[50.],
#        [70.],
#        [80.]])

# %%
X_train
# Out:
# array([[30.],
#        [20.],
#        [60.],
#        [40.],
#        [90.],
#        [10.]])

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform(X_train)

# %%
X_train_scaled
# Out:
# array([[0.25 ],
#        [0.125],
#        [0.625],
#        [0.375],
#        [1.   ],
#        [0.   ]])

# %%
ai_brain = Sequential([
    Dense(2,activation='relu'),
    Dense(1,activation='relu')
])

# %%
ai_brain.compile(optimizer='rmsprop',loss='mse')

# %%
ai_brain.fit(x=X_train_scaled,y=Y_train,epochs=20000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7474e-04
# Epoch 17502/20000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7509e-04
# Epoch 17503/20000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7530e-04
# Epoch 17504/20000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7539e-04
# Epoch 17505/20000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7531e-04
# Epoch 17506/20000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7530e-04
# Epoch 17507/20000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.7529e-04
# Epoch 17508/20000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7506e-04
# Epoch 17509/20000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7474e-04
# Epoch 17510/20000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7450e-04
# Epoch 17511/20000
# ...

# %%
loss_df = pd.DataFrame(ai_brain.history.history)

# %%
loss_df.plot()

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[0.5  ],
#        [0.75 ],
#        [0.875]])

# %%
ai_brain.evaluate(X_test_scaled,Y_test)
# Out:
# 1/1 [==============================] - 0s 114ms/step - loss: 2.7573e-04
# 0.0002757290785666555

# %%
input=[[100]]

# %%
input_scaled = scaler.transform(input)

# %%
input_scaled.shape
# Out:
# (1, 1)

# %%
input_scaled
# Out:
# array([[1.125]])

# %%
ai_brain.predict(input_scaled)
# Out:
# array([[205.02176]], dtype=float32)
